# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
import os
import shutil

# %matplotlib inline

# %%
import sklearn

# %%
img = cv2.imread('./test_images/LeBron James_25.jpg')
img.shape
# Out:
# (839, 474, 3)

# %%
plt.imshow(img);

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (839, 474)

# %%
gray
# Out:
# array([[ 25,  25,  25, ...,  22,  24,  24],
#        [ 25,  25,  25, ...,  22,  24,  24],
#        [ 25,  25,  25, ...,  22,  24,  24],
#        ...,
#        [201, 202, 187, ..., 128, 125, 111],
#        [207, 207, 203, ..., 131, 104,  69],
#        [201, 199, 201, ..., 132, 119,  71]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray');

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[100, 197, 255, 255]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (100, 197, 255, 255)

# %%
face_img = cv2.rectangle(img, (x,y), (x+w, y+h), (255, 0, 0), 2)
plt.imshow(face_img);

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img, (x,y), (x+w, y+w), (255,0,0), 2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex, ey, ew, eh) in eyes:
        cv2.rectangle(roi_color, (ex, ey), (ex+ew, ey+eh), (0,255,0), 2)
        
        
    
plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
plt.imshow(roi_color, cmap='gray');

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_images = cv2.imread('./test_images/LeBron James_25.jpg')
plt.imshow(original_images);

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/LeBron James_25.jpg')
plt.imshow(cropped_image);

# %%
org_image_obstructed = cv2.imread('./test_images/LeBron James_42.jpg')
plt.imshow(org_image_obstructed);

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test_images/LeBron James_42.jpg')
cropped_image_no_2_eyes

# %%
path_to_data = "./dataset"
path_to_cr_data = "./dataset/cropped"

# %%
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path.replace('\\','/'))

# %%
img_dirs
# Out:
# ['./dataset/Cristiano Ronaldo',
#  './dataset/cropped',
#  './dataset/LeBron James',
#  './dataset/Muhammad Ali',
#  './dataset/Serena Williams',
#  './dataset/Usain Bolt']

# %%
if os.path.exists(path_to_cr_data):
    shutil.rmtree(path_to_cr_data)
os.mkdir((path_to_cr_data))

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    if img_dir == './dataset/cropped': # Skip the second(cropped folder) item
        continue  # Skipped this iteration
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)
    
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + '/' + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ", cropped_folder)
                
            cropped_file_name = celebrity_name + str(count) + '.png'
            cropped_file_path = cropped_folder + '/' + cropped_file_name
            
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Cristiano Ronaldo
# Generating cropped images in folder:  ./dataset/cropped/Cristiano Ronaldo
# LeBron James
# Generating cropped images in folder:  ./dataset/cropped/LeBron James
# Muhammad Ali
# Generating cropped images in folder:  ./dataset/cropped/Muhammad Ali
# Serena Williams
# Generating cropped images in folder:  ./dataset/cropped/Serena Williams
# Usain Bolt
# Generating cropped images in folder:  ./dataset/cropped/Usain Bolt

# %%
import numpy as np
import pywt
import cv2

def w2d(img, mode='haar', level=1):
        imArray = img
        #Datatype conversion
        #Convert to grayscale
        imArray = cv2.cvtColor(imArray, cv2.COLOR_RGB2GRAY)
        #convert to float
        imArray = np.float32(imArray)
        imArray /= 255;
        #Compute coefficients
        coeffs = pywt.wavedec2(imArray, mode, level=level)
        
        #Process Coefficients
        coeffs_H = list(coeffs)
        coeffs_H[0] *= 0;
        
        #Reconstruction
        imArray_H = pywt.waverec2(coeffs_H, mode);
        imArray_H *= 255;
        imArray_H = np.uint8(imArray_H)
        
        return imArray_H

# %%
im_har = w2d(cropped_image, 'db1', 5)
plt.imshow(im_har, cmap='gray');

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'Cristiano Ronaldo': ['./dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo1.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo10.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo11.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo12.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo13.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo14.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo15.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo16.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo17.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo18.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo19.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo2.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo20.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo21.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo22.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo24.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo25.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo26.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo27.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo28.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo29.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo3.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo30.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo31.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo32.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo33.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo34.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo35.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo36.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo37.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo38.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo39.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo4.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo41.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo42.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo44.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo45.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo46.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo47.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo48.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo5.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo50.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo51.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo52.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo53.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo54.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo55.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo56.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo57.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo58.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo59.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo6.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo61.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo62.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo64.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo65.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo66.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo67.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo68.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo69.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo7.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo70.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo71.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo72.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo73.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo74.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo75.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo76.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo77.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo78.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo79.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo8.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo80.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo81.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo82.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo83.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo84.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo85.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo86.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo87.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo88.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo89.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo9.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo90.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo91.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo92.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo93.png',
#   './dataset/cropped/Cristiano Ronaldo\\Cristiano Ronaldo94.png'],
#  'LeBron James': ['./dataset/cropped/LeBron James\\LeBron James1.png',
#   './dataset/cropped/LeBron James\\LeBron James10.png',
#   './dataset/cropped/LeBron James\\LeBron James11.png',
#   './dataset/cropped/LeBron James\\LeBron James12.png',
#   './dataset/cropped/LeBron James\\LeBron James13.png',
#   './dataset/cropped/LeBron James\\LeBron James15.png',
#   './dataset/cropped/LeBron James\\LeBron James16.png',
#   './dataset/cropped/LeBron James\\LeBron James17.png',
#   './dataset/cropped/LeBron James\\LeBron James18.png',
#   './dataset/cropped/LeBron James\\LeBron James19.png',
#   './dataset/cropped/LeBron James\\LeBron James2.png',
#   './dataset/cropped/LeBron James\\LeBron James20.png',
#   './dataset/cropped/LeBron James\\LeBron James22.png',
#   './dataset/cropped/LeBron James\\LeBron James23.png',
#   './dataset/cropped/LeBron James\\LeBron James24.png',
#   './dataset/cropped/LeBron James\\LeBron James25.png',
#   './dataset/cropped/LeBron James\\LeBron James26.png',
#   './dataset/cropped/LeBron James\\LeBron James27.png',
#   './dataset/cropped/LeBron James\\LeBron James28.png',
#   './dataset/cropped/LeBron James\\LeBron James29.png',
#   './dataset/cropped/LeBron James\\LeBron James3.png',
#   './dataset/cropped/LeBron James\\LeBron James30.png',
#   './dataset/cropped/LeBron James\\LeBron James31.png',
#   './dataset/cropped/LeBron James\\LeBron James32.png',
#   './dataset/cropped/LeBron James\\LeBron James33.png',
#   './dataset/cropped/LeBron James\\LeBron James34.png',
#   './dataset/cropped/LeBron James\\LeBron James35.png',
#   './dataset/cropped/LeBron James\\LeBron James36.png',
#   './dataset/cropped/LeBron James\\LeBron James37.png',
#   './dataset/cropped/LeBron James\\LeBron James38.png',
#   './dataset/cropped/LeBron James\\LeBron James39.png',
#   './dataset/cropped/LeBron James\\LeBron James4.png',
#   './dataset/cropped/LeBron James\\LeBron James40.png',
#   './dataset/cropped/LeBron James\\LeBron James41.png',
#   './dataset/cropped/LeBron James\\LeBron James5.png',
#   './dataset/cropped/LeBron James\\LeBron James6.png',
#   './dataset/cropped/LeBron James\\LeBron James7.png',
#   './dataset/cropped/LeBron James\\LeBron James8.png',
#   './dataset/cropped/LeBron James\\LeBron James9.png'],
#  'Muhammad Ali': ['./dataset/cropped/Muhammad Ali\\Muhammad Ali1.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali10.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali11.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali12.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali13.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali14.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali15.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali16.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali17.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali18.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali19.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali2.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali20.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali21.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali22.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali23.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali24.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali25.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali26.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali27.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali28.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali29.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali3.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali30.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali31.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali32.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali33.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali34.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali35.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali36.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali37.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali38.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali39.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali4.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali40.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali41.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali43.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali44.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali45.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali46.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali47.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali48.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali49.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali5.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali50.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali51.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali52.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali6.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali7.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali8.png',
#   './dataset/cropped/Muhammad Ali\\Muhammad Ali9.png'],
#  'Serena Williams': ['./dataset/cropped/Serena Williams\\Serena Williams1.png',
#   './dataset/cropped/Serena Williams\\Serena Williams10.png',
#   './dataset/cropped/Serena Williams\\Serena Williams11.png',
#   './dataset/cropped/Serena Williams\\Serena Williams12.png',
#   './dataset/cropped/Serena Williams\\Serena Williams13.png',
#   './dataset/cropped/Serena Williams\\Serena Williams14.png',
#   './dataset/cropped/Serena Williams\\Serena Williams2.png',
#   './dataset/cropped/Serena Williams\\Serena Williams3.png',
#   './dataset/cropped/Serena Williams\\Serena Williams4.png',
#   './dataset/cropped/Serena Williams\\Serena Williams5.png',
#   './dataset/cropped/Serena Williams\\Serena Williams6.png',
#   './dataset/cropped/Serena Williams\\Serena Williams7.png',
#   './dataset/cropped/Serena Williams\\Serena Williams8.png',
#   './dataset/cropped/Serena Williams\\Serena Williams9.png'],
#  'Usain Bolt': ['./dataset/cropped/Usain Bolt\\Usain Bolt1.png',
#   './dataset/cropped/Usain Bolt\\Usain Bolt10.png',
#   './dataset/cropped/Usain Bolt\\Usain Bolt11.png',
#   './dataset/cropped/Usain Bolt\\Usain Bolt12.png',
#   './dataset/cropped/Usain Bolt\\Usain Bolt13.png',
#   './dataset/cropped/Usain Bolt\\Usain Bolt14.png',
#   './dataset/cropped/Usain Bolt\\Usain Bolt15.png',
#   './dataset/cropped/Usain Bolt\\Usain Bolt16.png',
#   './dataset/cropped/Usain Bolt\\Usain Bolt17.png',
#   './dataset/cropped/Usain Bolt\\Usain Bolt18.png',
#   './dataset/cropped/Usain Bolt\\Usain Bolt19.png',
#   './dataset/cropped/Usain Bolt\\Usain Bolt2.png',
#   './dataset/cropped/Usain Bolt\\Usain Bolt20.png',
#   './dataset/cropped/Usain Bolt\\Usain Bolt21.png',
#   './dataset/cropped/Usain Bolt\\Usain Bolt3.png',
#   './dataset/cropped/Usain Bolt\\Usain Bolt4.png',
#   './dataset/cropped/Usain Bolt\\Usain Bolt5.png',
#   './dataset/cropped/Usain Bolt\\Usain Bolt6.png',
#   './dataset/cropped/Usain Bolt\\Usain Bolt7.png',
#   './dataset/cropped/Usain Bolt\\Usain Bolt8.png',
#   './dataset/cropped/Usain Bolt\\Usain Bolt9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count += 1
class_dict
# Out:
# {'Cristiano Ronaldo': 0,
#  'LeBron James': 1,
#  'Muhammad Ali': 2,
#  'Serena Williams': 3,
#  'Usain Bolt': 4}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        if img is None:
            continue
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img, 'db1', 5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1), scalled_img_har.reshape(32*32, 1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
len(X[0])
# Out:
# 4096

# %%
X = np.array(X).reshape(len(X), 4096).astype(float)
X.shape
# Out:
# (213, 4096)

# %%
X[0]
# Out:
# array([ 62., 105.,  96., ...,  24.,  24.,  25.])

# %% [markdown]
# ## Model

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel='rbf', C=10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.8333333333333334

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.95      0.89        21
#            1       1.00      0.78      0.88         9
#            2       0.75      0.80      0.77        15
#            3       1.00      0.25      0.40         4
#            4       0.83      1.00      0.91         5
#
#     accuracy                           0.83        54
#    macro avg       0.88      0.76      0.77        54
# weighted avg       0.85      0.83      0.82        54

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto', probability=True),
        'params': {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf', 'linear']
        }
    },
    'random_forest': {
        'model':RandomForestClassifier(),
        'params': {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression':{
        'model': LogisticRegression(solver='liblinear'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf = GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores, columns=['model', 'best_score', 'best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.792540
# 1        random_forest    0.723790
# 2  logistic_regression    0.823589
#
#                                     best_params
# 0          {'svc__C': 10, 'svc__kernel': 'rbf'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                 {'logisticregression__C': 10}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc', SVC(C=10, gamma='auto', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=10, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test, y_test)
# Out:
# 0.8333333333333334

# %%
best_estimators['random_forest'].score(X_test, y_test)
# Out:
# 0.7592592592592593

# %%
best_estimators['logistic_regression'].score(X_test, y_test)
# Out:
# 0.9074074074074074

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[20,  0,  1,  0,  0],
#        [ 1,  7,  0,  0,  1],
#        [ 3,  0, 12,  0,  0],
#        [ 0,  0,  3,  1,  0],
#        [ 0,  0,  0,  0,  5]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'Cristiano Ronaldo': 0,
#  'LeBron James': 1,
#  'Muhammad Ali': 2,
#  'Serena Williams': 3,
#  'Usain Bolt': 4}

# %% [markdown]
# ### Save the trained model

# %%
#!pip install joblib
import joblib

# %%
# save the model as a pickle file
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# ['saved_model.pkl']

# %% [markdown]
# ### Save class dictionary

# %%
import json
with open('class_dictionary.json', 'w') as f:
    f.write(json.dumps(class_dict))
